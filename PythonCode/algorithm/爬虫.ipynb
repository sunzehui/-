# %%
# Out:
# 30000
# 30001
# 30002
# 30003
# 30004
# 30005
# 30006
# 30007
# 30008
# 30009
# 30010
# 30011
# 30012
# 30013
# 30014
# 30015
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-69aa4797e1b1> in <module>
#      21     }).text
#      22 for i in range(30000,40000):
# ---> 23     task(i)
#      24     print(i)
#
# <ipython-input-4-69aa4797e1b1> in task(id)
#       6
#       7 def task(id):
# ----> 8     return fetch("http://www.0818tuan.com/e/extend/lgyPl/doaction.php?ajax=1&_t=1611635112000", {
#       9       "headers": {
#      10         "accept": "application/json, text/javascript, */*; q=0.01",
#
# <ipython-input-4-69aa4797e1b1> in fetch(url, opt)
#       2 def fetch(url,opt):
#       3     if opt['method']=="POST":
# ----> 4         return requests.post(url,opt['body'],headers=opt['headers'])
#       5
#       6
#
# ...
